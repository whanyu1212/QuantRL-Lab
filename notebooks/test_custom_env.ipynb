# %%
import numpy as np
import gymnasium as gym
from quantrl_lab.custom_envs.stock.env_single_stock import StockTradingEnv
from quantrl_lab.custom_envs.stock.env_config import EnvConfig
from quantrl_lab.custom_envs.stock.strategies.actions.types.basic_market_actions import BasicActionStrategy
from quantrl_lab.custom_envs.stock.strategies.rewards.components import (
    PortfolioValueChangeReward,
    InvalidActionPenalty,
    TrendFollowingReward,
    HoldPenalty,
    BaseRewardStrategy
)
from quantrl_lab.custom_envs.stock.strategies.rewards.weighted_composite_reward import WeightedCompositeReward

# %%
portfolio_reward = PortfolioValueChangeReward()
invalid_penalty = InvalidActionPenalty(penalty=-1.0)
trend_reward = TrendFollowingReward()
hold_penalty = HoldPenalty(penalty=-0.005)

reward_components = [
    portfolio_reward,
    invalid_penalty,
    trend_reward,
    hold_penalty
]


component_weights = [
    1.0,  
    1.0,  
    0.5,  
    0.1   
]

composite_reward_strategy = WeightedCompositeReward(
    strategies=reward_components,
    weights=component_weights
)

# %%
def run_simple_test():

    print("=== 1. Setting up configuration and data ===")


    PRICE_COLUMN_INDEX = 3
    
    # Create dummy data for the environment
    data_size = 100
    my_data = np.random.rand(data_size, 5).astype(np.float32)
    my_data[:, PRICE_COLUMN_INDEX] = 50 + np.arange(data_size) * 0.2 + np.random.randn(data_size) * 0.5
    
    # Create the Pydantic config object
    env_configuration = EnvConfig(
        price_column_index=PRICE_COLUMN_INDEX,
        window_size=10,
        initial_balance=10000.0,
        transaction_cost_pct=0.001,
        slippage=0.0005            
    )

    # Instantiate the desired action strategy
    basic_action_strategy = BasicActionStrategy()

    print("Configuration, data, and strategy are ready.\n")

    # === 2. Initialize the Environment ===
    print("--- 2. Initializing the environment ---")
    try:
        env = StockTradingEnv(
            data=my_data,
            config=env_configuration,
            action_strategy=basic_action_strategy,
            reward_strategy=composite_reward_strategy
        )
        print("✅ Environment created successfully with FullActionStrategy!")
        print(f"Action Space: {env.action_space}")
        print(f"Observation Space Shape: {env.observation_space.shape}\n")
    except Exception as e:
        print(f"❌ Failed to create environment: {e}")
        return

    # === Run a few steps with random actions ===
    print("--- 3. Running a few steps with random actions ---")
    observation, info = env.reset()
    
    print("\n>>> Initial State after reset <<<")
    env.render(mode="human")

    num_random_steps = 50
    for i in range(num_random_steps):
        random_action = env.action_space.sample()

        print(f"\n{'='*40}")
        print(f"Step {i+1}/{num_random_steps} - Taking a random action")
        print(f"Random Action Array: {random_action}")
        print(f"{'='*40}")

        # Perform the step
        observation, reward, terminated, truncated, info = env.step(random_action)
        
        # Render the new state
        print("\n>>> State after action <<<")
        env.render(mode="human")

        # Print the key results from the info dictionary
        print(f"Reward received: {reward:.4f}")
        print(f"Decoded Action Info: {info['action_decoded']}")
        
        if terminated or truncated:
            print("\nEpisode finished early.")
            break
            
    print("\n\n=== Test finished successfully! ===")
    env.close()

# %%
run_simple_test()
# Out:
# === 1. Setting up configuration and data ===
# Configuration, data, and strategy are ready.
#
# --- 2. Initializing the environment ---
# ✅ Environment created successfully with FullActionStrategy!
# Action Space: Box([0.  0.  0.9], [6.  1.  1.1], (3,), float32)
# Observation Space Shape: (59,)
#
# --- 3. Running a few steps with random actions ---
#
# >>> Initial State after reset <<<
# ----------------------------------------
# Step:         10/99
# Current Price:          52.12
# Balance:             10000.00
# Shares Held:                0 (Free)
# Total Shares:               0 (Free + Reserved)
# Portfolio Val:       10000.00
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        0
#   Take Profit:      0
# ----------------------------------------
#
# ========================================
# Step 1/50 - Taking a random action
# Random Action Array: [0.18362254 0.88148165 1.015645  ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         11/99
# Current Price:          51.25
# Balance:             10000.00
# Shares Held:                0 (Free)
# Total Shares:               0 (Free + Reserved)
# Portfolio Val:       10000.00
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        0
#   Take Profit:      0
# ----------------------------------------
# Reward received: -0.0005
# Decoded Action Info: {'type': 'Hold', 'amount_pct': np.float32(0.88148165), 'price_modifier': np.float32(1.015645), 'raw_input': array([0.18362254, 0.88148165, 1.015645  ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 2/50 - Taking a random action
# Random Action Array: [1.4694427  0.44794688 0.95788836]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         12/99
# Current Price:          51.81
# Balance:              5534.89
# Shares Held:               87 (Free)
# Total Shares:              87 (Free + Reserved)
# Portfolio Val:       10042.77
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        0
#   Take Profit:      0
# ----------------------------------------
# Last Event:   market_buy (Shares: 87, Price: 51.27)
# ----------------------------------------
# Reward received: 0.0043
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.44794688), 'price_modifier': np.float32(0.95788836), 'raw_input': array([1.4694427 , 0.44794688, 0.95788836], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 3/50 - Taking a random action
# Random Action Array: [0.75186634 0.07052359 1.0060053 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         13/99
# Current Price:          52.36
# Balance:              5171.65
# Shares Held:               94 (Free)
# Total Shares:              94 (Free + Reserved)
# Portfolio Val:       10093.13
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        0
#   Take Profit:      0
# ----------------------------------------
# Last Event:   market_buy (Shares: 7, Price: 51.84)
# ----------------------------------------
# Reward received: 0.0050
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.07052359), 'price_modifier': np.float32(1.0060053), 'raw_input': array([0.75186634, 0.07052359, 1.0060053 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 4/50 - Taking a random action
# Random Action Array: [1.3177949  0.47821072 0.98208886]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         14/99
# Current Price:          52.45
# Balance:              2707.22
# Shares Held:              141 (Free)
# Total Shares:             141 (Free + Reserved)
# Portfolio Val:       10102.35
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        0
#   Take Profit:      0
# ----------------------------------------
# Last Event:   market_buy (Shares: 47, Price: 52.38)
# ----------------------------------------
# Reward received: 0.0009
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.47821072), 'price_modifier': np.float32(0.98208886), 'raw_input': array([1.3177949 , 0.47821072, 0.98208886], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 5/50 - Taking a random action
# Random Action Array: [1.7045932 0.9049054 1.0145367]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         15/99
# Current Price:          53.17
# Balance:              9358.09
# Shares Held:               14 (Free)
# Total Shares:              14 (Free + Reserved)
# Portfolio Val:       10102.49
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        0
#   Take Profit:      0
# ----------------------------------------
# Last Event:   market_sell (Shares: 127, Price: 52.42)
# ----------------------------------------
# Reward received: 0.0000
# Decoded Action Info: {'type': 'Sell', 'amount_pct': np.float32(0.9049054), 'price_modifier': np.float32(1.0145367), 'raw_input': array([1.7045932, 0.9049054, 1.0145367], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 6/50 - Taking a random action
# Random Action Array: [2.64644    0.39170444 1.0586094 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         16/99
# Current Price:          53.02
# Balance:              5695.73
# Shares Held:               14 (Free)
# Total Shares:              14 (Free + Reserved)
# Portfolio Val:        6437.97
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        0
#   Take Profit:      0
# ----------------------------------------
# Last Event:   limit_buy_placed (Shares: 65, Price: 56.287743)
# ----------------------------------------
# Reward received: -0.3627
# Decoded Action Info: {'type': 'LimitBuy', 'amount_pct': np.float32(0.39170444), 'price_modifier': np.float32(1.0586094), 'raw_input': array([2.64644   , 0.39170444, 1.0586094 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 7/50 - Taking a random action
# Random Action Array: [3.5153887 0.6066547 1.0093094]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         17/99
# Current Price:          52.93
# Balance:              5695.73
# Shares Held:               32 (Free)
# Total Shares:              79 (Free + Reserved)
# Portfolio Val:        9876.87
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        0
#   Take Profit:      0
# ----------------------------------------
# Last Event:   limit_sell_placed (Shares: 47, Price: 53.510452)
# ----------------------------------------
# Reward received: 0.5342
# Decoded Action Info: {'type': 'LimitSell', 'amount_pct': np.float32(0.6066547), 'price_modifier': np.float32(1.0093094), 'raw_input': array([3.5153887, 0.6066547, 1.0093094], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 8/50 - Taking a random action
# Random Action Array: [1.385111  0.9178156 0.9514072]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         18/99
# Current Price:          54.01
# Balance:               501.21
# Shares Held:              130 (Free)
# Total Shares:             177 (Free + Reserved)
# Portfolio Val:       10061.63
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        0
#   Take Profit:      0
# ----------------------------------------
# Last Event:   market_buy (Shares: 98, Price: 52.95)
# ----------------------------------------
# Reward received: 0.0187
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.9178156), 'price_modifier': np.float32(0.9514072), 'raw_input': array([1.385111 , 0.9178156, 0.9514072], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 9/50 - Taking a random action
# Random Action Array: [2.2176723  0.56798005 1.0351112 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         19/99
# Current Price:          53.78
# Balance:              6950.77
# Shares Held:               57 (Free)
# Total Shares:              57 (Free + Reserved)
# Portfolio Val:       10016.11
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        0
#   Take Profit:      0
# ----------------------------------------
# Last Event:   market_sell (Shares: 73, Price: 53.99)
# ----------------------------------------
# Reward received: -0.0045
# Decoded Action Info: {'type': 'Sell', 'amount_pct': np.float32(0.56798005), 'price_modifier': np.float32(1.0351112), 'raw_input': array([2.2176723 , 0.56798005, 1.0351112 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 10/50 - Taking a random action
# Random Action Array: [3.2307303  0.96242964 0.9187451 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         20/99
# Current Price:          53.38
# Balance:               274.00
# Shares Held:               57 (Free)
# Total Shares:              57 (Free + Reserved)
# Portfolio Val:        3316.53
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        0
#   Take Profit:      0
# ----------------------------------------
# Last Event:   limit_buy_placed (Shares: 135, Price: 49.40812)
# ----------------------------------------
# Reward received: -0.6689
# Decoded Action Info: {'type': 'LimitBuy', 'amount_pct': np.float32(0.96242964), 'price_modifier': np.float32(0.9187451), 'raw_input': array([3.2307303 , 0.96242964, 0.9187451 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 11/50 - Taking a random action
# Random Action Array: [4.520968  0.3330861 1.0657245]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         21/99
# Current Price:          54.70
# Balance:               274.00
# Shares Held:               39 (Free)
# Total Shares:              57 (Free + Reserved)
# Portfolio Val:        3391.96
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        1
#   Take Profit:      0
# ----------------------------------------
# Last Event:   stop_loss_placed (Shares: 18, Price: 53.32)
# ----------------------------------------
# Reward received: 0.0227
# Decoded Action Info: {'type': 'StopLoss', 'amount_pct': np.float32(0.3330861), 'price_modifier': np.float32(1.0657245), 'raw_input': array([4.520968 , 0.3330861, 1.0657245], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 12/50 - Taking a random action
# Random Action Array: [3.0786173  0.01334377 1.026402  ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         22/99
# Current Price:          53.85
# Balance:               274.00
# Shares Held:               39 (Free)
# Total Shares:              57 (Free + Reserved)
# Portfolio Val:        3343.74
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        1
#   Take Profit:      0
# ----------------------------------------
# Last Event:   stop_loss_placed (Shares: 18, Price: 53.32)
# ----------------------------------------
# Reward received: -0.0142
# Decoded Action Info: {'type': 'LimitBuy', 'amount_pct': np.float32(0.013343769), 'price_modifier': np.float32(1.026402), 'raw_input': array([3.0786173 , 0.01334377, 1.026402  ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 13/50 - Taking a random action
# Random Action Array: [5.8680606  0.15625918 1.0700936 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         23/99
# Current Price:          54.82
# Balance:               274.00
# Shares Held:               33 (Free)
# Total Shares:              57 (Free + Reserved)
# Portfolio Val:        3398.70
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        1
#   Take Profit:      1
# ----------------------------------------
# Last Event:   take_profit_placed (Shares: 6, Price: 57.62983)
# ----------------------------------------
# Reward received: 0.0415
# Decoded Action Info: {'type': 'TakeProfit', 'amount_pct': np.float32(0.15625918), 'price_modifier': np.float32(1.0700936), 'raw_input': array([5.8680606 , 0.15625918, 1.0700936 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 14/50 - Taking a random action
# Random Action Array: [3.8258638 0.1193506 1.0545652]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         24/99
# Current Price:          54.79
# Balance:               274.00
# Shares Held:               30 (Free)
# Total Shares:              57 (Free + Reserved)
# Portfolio Val:        3396.76
# ----------------------------------------
# Active Orders:
#   Pending Limit:    2
#   Stop Loss:        1
#   Take Profit:      1
# ----------------------------------------
# Last Event:   limit_sell_placed (Shares: 3, Price: 57.81053)
# ----------------------------------------
# Reward received: -0.0006
# Decoded Action Info: {'type': 'LimitSell', 'amount_pct': np.float32(0.1193506), 'price_modifier': np.float32(1.0545652), 'raw_input': array([3.8258638, 0.1193506, 1.0545652], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 15/50 - Taking a random action
# Random Action Array: [3.2287858  0.24825664 1.0016671 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         25/99
# Current Price:          54.96
# Balance:               219.07
# Shares Held:               30 (Free)
# Total Shares:              57 (Free + Reserved)
# Portfolio Val:        3352.07
# ----------------------------------------
# Active Orders:
#   Pending Limit:    3
#   Stop Loss:        1
#   Take Profit:      1
# ----------------------------------------
# Last Event:   limit_buy_placed (Shares: 1, Price: 54.876526)
# ----------------------------------------
# Reward received: -0.0132
# Decoded Action Info: {'type': 'LimitBuy', 'amount_pct': np.float32(0.24825664), 'price_modifier': np.float32(1.0016671), 'raw_input': array([3.2287858 , 0.24825664, 1.0016671 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 16/50 - Taking a random action
# Random Action Array: [5.1131    0.6564189 1.0914341]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         26/99
# Current Price:          55.15
# Balance:              6895.84
# Shares Held:               11 (Free)
# Total Shares:              57 (Free + Reserved)
# Portfolio Val:       10039.41
# ----------------------------------------
# Active Orders:
#   Pending Limit:    2
#   Stop Loss:        2
#   Take Profit:      1
# ----------------------------------------
# Last Event:   stop_loss_placed (Shares: 19, Price: 54.91)
# ----------------------------------------
# Reward received: 1.9950
# Decoded Action Info: {'type': 'StopLoss', 'amount_pct': np.float32(0.6564189), 'price_modifier': np.float32(1.0914341), 'raw_input': array([5.1131   , 0.6564189, 1.0914341], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 17/50 - Taking a random action
# Random Action Array: [1.2518396  0.00859901 0.9314373 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         27/99
# Current Price:          55.82
# Balance:              6840.61
# Shares Held:               12 (Free)
# Total Shares:              58 (Free + Reserved)
# Portfolio Val:       10077.94
# ----------------------------------------
# Active Orders:
#   Pending Limit:    2
#   Stop Loss:        2
#   Take Profit:      1
# ----------------------------------------
# Last Event:   market_buy (Shares: 1, Price: 55.18)
# ----------------------------------------
# Reward received: 0.0038
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.008599015), 'price_modifier': np.float32(0.9314373), 'raw_input': array([1.2518396 , 0.00859901, 0.9314373 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 18/50 - Taking a random action
# Random Action Array: [4.7143106  0.29401454 0.9736497 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         28/99
# Current Price:          56.19
# Balance:              6840.61
# Shares Held:                9 (Free)
# Total Shares:              58 (Free + Reserved)
# Portfolio Val:       10099.46
# ----------------------------------------
# Active Orders:
#   Pending Limit:    2
#   Stop Loss:        3
#   Take Profit:      1
# ----------------------------------------
# Last Event:   stop_loss_placed (Shares: 3, Price: 54.345375)
# ----------------------------------------
# Reward received: 0.0021
# Decoded Action Info: {'type': 'StopLoss', 'amount_pct': np.float32(0.29401454), 'price_modifier': np.float32(0.9736497), 'raw_input': array([4.7143106 , 0.29401454, 0.9736497 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 19/50 - Taking a random action
# Random Action Array: [0.07048191 0.7617593  1.0819155 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         29/99
# Current Price:          55.85
# Balance:              6840.61
# Shares Held:                9 (Free)
# Total Shares:              58 (Free + Reserved)
# Portfolio Val:       10080.10
# ----------------------------------------
# Active Orders:
#   Pending Limit:    2
#   Stop Loss:        3
#   Take Profit:      1
# ----------------------------------------
# Last Event:   stop_loss_placed (Shares: 3, Price: 54.345375)
# ----------------------------------------
# Reward received: -0.0024
# Decoded Action Info: {'type': 'Hold', 'amount_pct': np.float32(0.7617593), 'price_modifier': np.float32(1.0819155), 'raw_input': array([0.07048191, 0.7617593 , 1.0819155 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 20/50 - Taking a random action
# Random Action Array: [4.9833374 0.1484858 1.0419744]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         30/99
# Current Price:          55.06
# Balance:              6840.61
# Shares Held:               11 (Free)
# Total Shares:              58 (Free + Reserved)
# Portfolio Val:       10034.03
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        4
#   Take Profit:      1
# ----------------------------------------
# Last Event:   stop_loss_placed (Shares: 1, Price: 55.80)
# ----------------------------------------
# Reward received: -0.0046
# Decoded Action Info: {'type': 'StopLoss', 'amount_pct': np.float32(0.1484858), 'price_modifier': np.float32(1.0419744), 'raw_input': array([4.9833374, 0.1484858, 1.0419744], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 21/50 - Taking a random action
# Random Action Array: [4.3895693  0.32672924 0.9248662 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         31/99
# Current Price:          56.27
# Balance:              6950.51
# Shares Held:                8 (Free)
# Total Shares:              57 (Free + Reserved)
# Portfolio Val:       10158.09
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        3
#   Take Profit:      1
# ----------------------------------------
# Last Event:   limit_sell_placed (Shares: 3, Price: 50.9223)
# ----------------------------------------
# Reward received: 0.0124
# Decoded Action Info: {'type': 'LimitSell', 'amount_pct': np.float32(0.32672924), 'price_modifier': np.float32(0.9248662), 'raw_input': array([4.3895693 , 0.32672924, 0.9248662 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 22/50 - Taking a random action
# Random Action Array: [0.65803933 0.83569    0.9221391 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         32/99
# Current Price:          54.93
# Balance:              1185.57
# Shares Held:              113 (Free)
# Total Shares:             159 (Free + Reserved)
# Portfolio Val:        9920.04
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        3
#   Take Profit:      1
# ----------------------------------------
# Last Event:   market_buy (Shares: 105, Price: 56.30)
# ----------------------------------------
# Reward received: -0.0234
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.83569), 'price_modifier': np.float32(0.9221391), 'raw_input': array([0.65803933, 0.83569   , 0.9221391 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 23/50 - Taking a random action
# Random Action Array: [3.5985363 0.2684357 0.9082691]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         33/99
# Current Price:          56.45
# Balance:              1185.57
# Shares Held:               83 (Free)
# Total Shares:             159 (Free + Reserved)
# Portfolio Val:       10161.44
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        3
#   Take Profit:      1
# ----------------------------------------
# Last Event:   limit_sell_placed (Shares: 30, Price: 49.894665)
# ----------------------------------------
# Reward received: 0.0243
# Decoded Action Info: {'type': 'LimitSell', 'amount_pct': np.float32(0.2684357), 'price_modifier': np.float32(0.9082691), 'raw_input': array([3.5985363, 0.2684357, 0.9082691], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 24/50 - Taking a random action
# Random Action Array: [3.4310396  0.81415385 0.95127124]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         34/99
# Current Price:          57.44
# Balance:               530.72
# Shares Held:               83 (Free)
# Total Shares:             129 (Free + Reserved)
# Portfolio Val:        7940.94
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        3
#   Take Profit:      1
# ----------------------------------------
# Last Event:   limit_buy_placed (Shares: 40, Price: 53.701183)
# ----------------------------------------
# Reward received: -0.2185
# Decoded Action Info: {'type': 'LimitBuy', 'amount_pct': np.float32(0.81415385), 'price_modifier': np.float32(0.95127124), 'raw_input': array([3.4310396 , 0.81415385, 0.95127124], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 25/50 - Taking a random action
# Random Action Array: [5.1506042  0.8990577  0.90106106]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         35/99
# Current Price:          57.37
# Balance:               530.72
# Shares Held:                9 (Free)
# Total Shares:             129 (Free + Reserved)
# Portfolio Val:        7930.87
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        4
#   Take Profit:      1
# ----------------------------------------
# Last Event:   stop_loss_placed (Shares: 74, Price: 51.760162)
# ----------------------------------------
# Reward received: -0.0013
# Decoded Action Info: {'type': 'StopLoss', 'amount_pct': np.float32(0.8990577), 'price_modifier': np.float32(0.90106106), 'raw_input': array([5.1506042 , 0.8990577 , 0.90106106], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 26/50 - Taking a random action
# Random Action Array: [4.336482   0.5339412  0.94757926]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         36/99
# Current Price:          56.99
# Balance:               530.72
# Shares Held:                5 (Free)
# Total Shares:             129 (Free + Reserved)
# Portfolio Val:        7882.50
# ----------------------------------------
# Active Orders:
#   Pending Limit:    2
#   Stop Loss:        4
#   Take Profit:      1
# ----------------------------------------
# Last Event:   limit_sell_placed (Shares: 4, Price: 54.35835)
# ----------------------------------------
# Reward received: -0.0061
# Decoded Action Info: {'type': 'LimitSell', 'amount_pct': np.float32(0.5339412), 'price_modifier': np.float32(0.94757926), 'raw_input': array([4.336482  , 0.5339412 , 0.94757926], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 27/50 - Taking a random action
# Random Action Array: [4.2334347 0.9194961 1.0666375]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         37/99
# Current Price:          56.87
# Balance:               747.93
# Shares Held:                1 (Free)
# Total Shares:             125 (Free + Reserved)
# Portfolio Val:        7856.29
# ----------------------------------------
# Active Orders:
#   Pending Limit:    2
#   Stop Loss:        4
#   Take Profit:      1
# ----------------------------------------
# Last Event:   limit_sell_placed (Shares: 4, Price: 60.788265)
# ----------------------------------------
# Reward received: -0.0033
# Decoded Action Info: {'type': 'LimitSell', 'amount_pct': np.float32(0.9194961), 'price_modifier': np.float32(1.0666375), 'raw_input': array([4.2334347, 0.9194961, 1.0666375], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 28/50 - Taking a random action
# Random Action Array: [1.7503307  0.8687515  0.98859906]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         38/99
# Current Price:          58.60
# Balance:               747.93
# Shares Held:                1 (Free)
# Total Shares:             125 (Free + Reserved)
# Portfolio Val:        8073.38
# ----------------------------------------
# Active Orders:
#   Pending Limit:    2
#   Stop Loss:        4
#   Take Profit:      1
# ----------------------------------------
# Last Event:   limit_sell_placed (Shares: 4, Price: 60.788265)
# ----------------------------------------
# Reward received: 0.0276
# Decoded Action Info: {'type': 'Sell', 'amount_pct': np.float32(0.8687515), 'price_modifier': np.float32(0.98859906), 'raw_input': array([1.7503307 , 0.8687515 , 0.98859906], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 29/50 - Taking a random action
# Random Action Array: [1.8669552  0.83283067 0.96934235]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         39/99
# Current Price:          58.31
# Balance:              1099.03
# Shares Held:                1 (Free)
# Total Shares:             119 (Free + Reserved)
# Portfolio Val:        8037.60
# ----------------------------------------
# Active Orders:
#   Pending Limit:    2
#   Stop Loss:        4
#   Take Profit:      0
# ----------------------------------------
# Last Event:   take_profit_executed (Shares: 6, Price: None)
# ----------------------------------------
# Reward received: -0.0044
# Decoded Action Info: {'type': 'Sell', 'amount_pct': np.float32(0.83283067), 'price_modifier': np.float32(0.96934235), 'raw_input': array([1.8669552 , 0.83283067, 0.96934235], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 30/50 - Taking a random action
# Random Action Array: [3.6271307  0.60315573 1.0248319 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         40/99
# Current Price:          58.44
# Balance:              3249.22
# Shares Held:                1 (Free)
# Total Shares:             119 (Free + Reserved)
# Portfolio Val:       10203.29
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        4
#   Take Profit:      0
# ----------------------------------------
# Last Event:   limit_buy_expired (Shares: 40, Price: 53.701183)
# ----------------------------------------
# Reward received: 0.2694
# Decoded Action Info: {'type': 'LimitSell', 'amount_pct': np.float32(0.60315573), 'price_modifier': np.float32(1.0248319), 'raw_input': array([3.6271307 , 0.60315573, 1.0248319 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 31/50 - Taking a random action
# Random Action Array: [0.9876072  0.56877196 0.93185127]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         41/99
# Current Price:          57.03
# Balance:              1434.94
# Shares Held:               32 (Free)
# Total Shares:             150 (Free + Reserved)
# Portfolio Val:        9989.45
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        4
#   Take Profit:      0
# ----------------------------------------
# Last Event:   market_buy (Shares: 31, Price: 58.47)
# ----------------------------------------
# Reward received: -0.0210
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.56877196), 'price_modifier': np.float32(0.93185127), 'raw_input': array([0.9876072 , 0.56877196, 0.93185127], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 32/50 - Taking a random action
# Random Action Array: [3.484584  0.1099338 1.0883148]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         42/99
# Current Price:          57.85
# Balance:              1310.68
# Shares Held:               32 (Free)
# Total Shares:             150 (Free + Reserved)
# Portfolio Val:        9988.25
# ----------------------------------------
# Active Orders:
#   Pending Limit:    2
#   Stop Loss:        4
#   Take Profit:      0
# ----------------------------------------
# Last Event:   limit_buy_placed (Shares: 2, Price: 62.066654)
# ----------------------------------------
# Reward received: -0.0001
# Decoded Action Info: {'type': 'LimitBuy', 'amount_pct': np.float32(0.1099338), 'price_modifier': np.float32(1.0883148), 'raw_input': array([3.484584 , 0.1099338, 1.0883148], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 33/50 - Taking a random action
# Random Action Array: [0.65485126 0.71745837 0.98250943]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         43/99
# Current Price:          59.15
# Balance:               383.69
# Shares Held:               54 (Free)
# Total Shares:             168 (Free + Reserved)
# Portfolio Val:       10320.81
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        4
#   Take Profit:      0
# ----------------------------------------
# Last Event:   market_buy (Shares: 16, Price: 57.88)
# ----------------------------------------
# Reward received: 0.0333
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.71745837), 'price_modifier': np.float32(0.98250943), 'raw_input': array([0.65485126, 0.71745837, 0.98250943], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 34/50 - Taking a random action
# Random Action Array: [1.176007  0.0375085 0.9541754]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         44/99
# Current Price:          58.10
# Balance:               383.69
# Shares Held:               54 (Free)
# Total Shares:             168 (Free + Reserved)
# Portfolio Val:       10144.08
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        4
#   Take Profit:      0
# ----------------------------------------
# Last Event:   market_buy (Shares: 16, Price: 57.88)
# ----------------------------------------
# Reward received: -0.0171
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.037508503), 'price_modifier': np.float32(0.9541754), 'raw_input': array([1.176007 , 0.0375085, 0.9541754], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 35/50 - Taking a random action
# Random Action Array: [0.8537183 0.9698658 1.0332402]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         45/99
# Current Price:          59.18
# Balance:                34.58
# Shares Held:               60 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10331.28
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        4
#   Take Profit:      0
# ----------------------------------------
# Last Event:   market_buy (Shares: 6, Price: 58.13)
# ----------------------------------------
# Reward received: 0.0185
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.9698658), 'price_modifier': np.float32(1.0332402), 'raw_input': array([0.8537183, 0.9698658, 1.0332402], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 36/50 - Taking a random action
# Random Action Array: [5.9982123 0.5146155 1.0996048]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         46/99
# Current Price:          59.35
# Balance:                34.58
# Shares Held:               30 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10360.77
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        4
#   Take Profit:      1
# ----------------------------------------
# Last Event:   take_profit_placed (Shares: 30, Price: 65.07068)
# ----------------------------------------
# Reward received: 0.0279
# Decoded Action Info: {'type': 'TakeProfit', 'amount_pct': np.float32(0.5146155), 'price_modifier': np.float32(1.0996048), 'raw_input': array([5.9982123, 0.5146155, 1.0996048], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 37/50 - Taking a random action
# Random Action Array: [3.4501162  0.14600603 1.0951953 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         47/99
# Current Price:          58.48
# Balance:                34.58
# Shares Held:               30 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10210.88
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        4
#   Take Profit:      1
# ----------------------------------------
# Last Event:   take_profit_placed (Shares: 30, Price: 65.07068)
# ----------------------------------------
# Reward received: -0.0145
# Decoded Action Info: {'type': 'LimitBuy', 'amount_pct': np.float32(0.14600603), 'price_modifier': np.float32(1.0951953), 'raw_input': array([3.4501162 , 0.14600603, 1.0951953 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 38/50 - Taking a random action
# Random Action Array: [0.89147943 0.56436026 1.0706362 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         48/99
# Current Price:          59.51
# Balance:                34.58
# Shares Held:               30 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10388.59
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        4
#   Take Profit:      1
# ----------------------------------------
# Last Event:   take_profit_placed (Shares: 30, Price: 65.07068)
# ----------------------------------------
# Reward received: 0.0174
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.56436026), 'price_modifier': np.float32(1.0706362), 'raw_input': array([0.89147943, 0.56436026, 1.0706362 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 39/50 - Taking a random action
# Random Action Array: [1.4915553 0.625311  0.9656173]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         49/99
# Current Price:          59.70
# Balance:                34.58
# Shares Held:               30 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10422.53
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        4
#   Take Profit:      1
# ----------------------------------------
# Last Event:   take_profit_placed (Shares: 30, Price: 65.07068)
# ----------------------------------------
# Reward received: 0.0033
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.625311), 'price_modifier': np.float32(0.9656173), 'raw_input': array([1.4915553, 0.625311 , 0.9656173], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 40/50 - Taking a random action
# Random Action Array: [4.7922626  0.4102749  0.95154405]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         50/99
# Current Price:          61.13
# Balance:                34.58
# Shares Held:               18 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10671.77
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        5
#   Take Profit:      1
# ----------------------------------------
# Last Event:   stop_loss_placed (Shares: 12, Price: 56.80801)
# ----------------------------------------
# Reward received: 0.0239
# Decoded Action Info: {'type': 'StopLoss', 'amount_pct': np.float32(0.4102749), 'price_modifier': np.float32(0.95154405), 'raw_input': array([4.7922626 , 0.4102749 , 0.95154405], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 41/50 - Taking a random action
# Random Action Array: [3.463705   0.4257951  0.90983135]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         51/99
# Current Price:          60.43
# Balance:                34.58
# Shares Held:               18 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10548.88
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        5
#   Take Profit:      1
# ----------------------------------------
# Last Event:   stop_loss_placed (Shares: 12, Price: 56.80801)
# ----------------------------------------
# Reward received: -0.0115
# Decoded Action Info: {'type': 'LimitBuy', 'amount_pct': np.float32(0.4257951), 'price_modifier': np.float32(0.90983135), 'raw_input': array([3.463705  , 0.4257951 , 0.90983135], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 42/50 - Taking a random action
# Random Action Array: [0.49267796 0.03166919 1.0909511 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         52/99
# Current Price:          60.36
# Balance:                34.58
# Shares Held:               18 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10536.35
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        5
#   Take Profit:      1
# ----------------------------------------
# Last Event:   stop_loss_placed (Shares: 12, Price: 56.80801)
# ----------------------------------------
# Reward received: -0.0017
# Decoded Action Info: {'type': 'Hold', 'amount_pct': np.float32(0.031669192), 'price_modifier': np.float32(1.0909511), 'raw_input': array([0.49267796, 0.03166919, 1.0909511 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 43/50 - Taking a random action
# Random Action Array: [5.192554  0.7078087 1.0612515]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         53/99
# Current Price:          60.83
# Balance:                34.58
# Shares Held:                6 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10619.02
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        6
#   Take Profit:      1
# ----------------------------------------
# Last Event:   stop_loss_placed (Shares: 12, Price: 60.29)
# ----------------------------------------
# Reward received: 0.0078
# Decoded Action Info: {'type': 'StopLoss', 'amount_pct': np.float32(0.7078087), 'price_modifier': np.float32(1.0612515), 'raw_input': array([5.192554 , 0.7078087, 1.0612515], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 44/50 - Taking a random action
# Random Action Array: [5.9895654  0.17552947 1.0638956 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         54/99
# Current Price:          60.47
# Balance:                34.58
# Shares Held:                5 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10555.82
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        6
#   Take Profit:      2
# ----------------------------------------
# Last Event:   take_profit_placed (Shares: 1, Price: 64.71692)
# ----------------------------------------
# Reward received: 0.0191
# Decoded Action Info: {'type': 'TakeProfit', 'amount_pct': np.float32(0.17552947), 'price_modifier': np.float32(1.0638956), 'raw_input': array([5.9895654 , 0.17552947, 1.0638956 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 45/50 - Taking a random action
# Random Action Array: [0.6754038 0.7766218 1.0377042]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         55/99
# Current Price:          60.41
# Balance:                34.58
# Shares Held:                5 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10545.38
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        6
#   Take Profit:      2
# ----------------------------------------
# Last Event:   take_profit_placed (Shares: 1, Price: 64.71692)
# ----------------------------------------
# Reward received: -0.0010
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.7766218), 'price_modifier': np.float32(1.0377042), 'raw_input': array([0.6754038, 0.7766218, 1.0377042], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 46/50 - Taking a random action
# Random Action Array: [5.8708825  0.89288706 0.94133645]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         56/99
# Current Price:          61.69
# Balance:                34.58
# Shares Held:                1 (Free)
# Total Shares:             174 (Free + Reserved)
# Portfolio Val:       10768.77
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        6
#   Take Profit:      3
# ----------------------------------------
# Last Event:   take_profit_placed (Shares: 4, Price: 60.47)
# ----------------------------------------
# Reward received: 0.0463
# Decoded Action Info: {'type': 'TakeProfit', 'amount_pct': np.float32(0.89288706), 'price_modifier': np.float32(0.94133645), 'raw_input': array([5.8708825 , 0.89288706, 0.94133645], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 47/50 - Taking a random action
# Random Action Array: [5.983218 0.516519 0.929727]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         57/99
# Current Price:          61.24
# Balance:               280.97
# Shares Held:                1 (Free)
# Total Shares:             170 (Free + Reserved)
# Portfolio Val:       10692.15
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        6
#   Take Profit:      2
# ----------------------------------------
# Last Event:   take_profit_executed (Shares: 4, Price: None)
# ----------------------------------------
# Reward received: 0.0179
# Decoded Action Info: {'type': 'TakeProfit', 'amount_pct': np.float32(0.516519), 'price_modifier': np.float32(0.929727), 'raw_input': array([5.983218, 0.516519, 0.929727], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 48/50 - Taking a random action
# Random Action Array: [5.241208   0.83734894 0.9500451 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         58/99
# Current Price:          62.08
# Balance:               280.97
# Shares Held:                1 (Free)
# Total Shares:             170 (Free + Reserved)
# Portfolio Val:       10835.23
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        6
#   Take Profit:      2
# ----------------------------------------
# Last Event:   take_profit_executed (Shares: 4, Price: None)
# ----------------------------------------
# Reward received: 0.0134
# Decoded Action Info: {'type': 'StopLoss', 'amount_pct': np.float32(0.83734894), 'price_modifier': np.float32(0.9500451), 'raw_input': array([5.241208  , 0.83734894, 0.9500451 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 49/50 - Taking a random action
# Random Action Array: [0.79274553 0.6575412  1.0188775 ]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         59/99
# Current Price:          62.27
# Balance:               156.62
# Shares Held:                3 (Free)
# Total Shares:             172 (Free + Reserved)
# Portfolio Val:       10867.07
# ----------------------------------------
# Active Orders:
#   Pending Limit:    0
#   Stop Loss:        6
#   Take Profit:      2
# ----------------------------------------
# Last Event:   market_buy (Shares: 2, Price: 62.11)
# ----------------------------------------
# Reward received: 0.0029
# Decoded Action Info: {'type': 'Buy', 'amount_pct': np.float32(0.6575412), 'price_modifier': np.float32(1.0188775), 'raw_input': array([0.79274553, 0.6575412 , 1.0188775 ], dtype=float32), 'invalid_action_attempt': False}
#
# ========================================
# Step 50/50 - Taking a random action
# Random Action Array: [2.9480736  0.5813563  0.94555295]
# ========================================
#
# >>> State after action <<<
# ----------------------------------------
# Step:         60/99
# Current Price:          62.03
# Balance:                97.68
# Shares Held:                3 (Free)
# Total Shares:             172 (Free + Reserved)
# Portfolio Val:       10766.42
# ----------------------------------------
# Active Orders:
#   Pending Limit:    1
#   Stop Loss:        6
#   Take Profit:      2
# ----------------------------------------
# Last Event:   limit_buy_placed (Shares: 1, Price: 58.879627)
# ----------------------------------------
# Reward received: -0.0093
# Decoded Action Info: {'type': 'LimitBuy', 'amount_pct': np.float32(0.5813563), 'price_modifier': np.float32(0.94555295), 'raw_input': array([2.9480736 , 0.5813563 , 0.94555295], dtype=float32), 'invalid_action_attempt': False}
#
#
# === Test finished successfully! ===
# StockTradingEnvMultiFeature closed.
